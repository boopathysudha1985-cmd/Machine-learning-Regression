# %%
import pickle

# %%
loaded_model=pickle.load(open("finalized_model_Forest_sav",'rb'))
result=loaded_model.predict([[0,1,2,3,4,]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([35874.2715])

# %%
loaded_model=pickle.load(open("finalized_model_Forest_sav",'rb'))
result=loaded_model.predict([[1234,345,4565,1,0]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([50022.5385])

# %%
loaded_model=pickle.load(open("finalized_model_Forest_sav",'rb'))
result=loaded_model.predict([[1244,365,6565,3,0]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([50022.5385])
